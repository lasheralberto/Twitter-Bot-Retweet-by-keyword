# %%
import tweepy as tw

consumer_key= 'yQ4xnp7UG64FkmSc88zQRB4Kk'
consumer_secret= 'fSxHYYL3PjiNhAsn0IhLgQNogC5N2qOWBtGokDAlEWrJFi6CuZ'
access_token= '1139599692684300288-CjLtSZxQVYoWa86PQlpHvYBuHs1hqn'
access_token_secret= 'eqA6quZ27JEMOaFeDOCfVjqzSQjpR9RvOWV6QRvP8GuZR'

auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

try:
    api.verify_credentials()
    print("Authentication OK")
except:
    print("Error during authentication")
# Out:
# Authentication OK

# %%
# tweepy-bots/bots/config.py
import tweepy
import logging
import os
import json

logger = logging.getLogger()

def create_api():
    consumer_key= 'yQ4xnp7UG64FkmSc88zQRB4Kk'
    consumer_secret= 'fSxHYYL3PjiNhAsn0IhLgQNogC5N2qOWBtGokDAlEWrJFi6CuZ'
    access_token= '1139599692684300288-CjLtSZxQVYoWa86PQlpHvYBuHs1hqn'
    access_token_secret= 'eqA6quZ27JEMOaFeDOCfVjqzSQjpR9RvOWV6QRvP8GuZR'

    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    api = tweepy.API(auth, wait_on_rate_limit=True, 
        wait_on_rate_limit_notify=True)
    try:
        api.verify_credentials()
    except Exception as e:
        logger.error("Error creating API", exc_info=True)
        raise e
    logger.info("API created")
    return api

create_api()



logging.basicConfig(level=logging.INFO)
logger = logging.getLogger()

class FavRetweetListener(tweepy.StreamListener):
    def __init__(self, api):
        self.api = api
        self.me = api.me()

    def on_status(self, tweet):
        logger.info(f"Processing tweet id {tweet.id}")
        if tweet.in_reply_to_status_id is not None or \
            tweet.user.id == self.me.id:
            # This tweet is a reply or I'm its author so, ignore it
            return
        if not tweet.favorited:
            # Mark it as Liked, since we have not done it yet
            try:
                tweet.favorite()
            except Exception as e:
                logger.error("Error on fav", exc_info=True)
        if not tweet.retweeted:
            # Retweet, since we have not retweeted it yet
            try:
                tweet.retweet()
            except Exception as e:
                logger.error("Error on fav and retweet", exc_info=True)

    def on_error(self, status):
        logger.error(status)

def main(keywords):
    
    api = create_api()
    tweets_listener = FavRetweetListener(api)
    stream = tweepy.Stream(api.auth, tweets_listener)
    stream.filter(track=keywords, languages=["es"])

if __name__ == "__main__":
    main(["VOX"])
# Out:
# line 48, in on_status
#     tweet.favorite()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\models.py", line 131, in favorite
#     return self._api.create_favorite(self.id)
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 253, in _call
#     return method.execute()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 234, in execute
#     raise TweepError(error_msg, resp, api_code=api_error_code)
# tweepy.error.TweepError: Twitter error response: status code = 429
# ERROR:root:Error on fav and retweet
# Traceback (most recent call last):
#   File "<ipython-input-4-c4d251994a9b>", line 54, in on_status
#     tweet.retweet()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\models.py", line 125, in retweet
#     return self._api.retweet(self.id)
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 253, in _call
#     return method.execute()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 234, in execute
#     raise TweepError(error_msg, resp, api_code=api_error_code)
# tweepy.error.TweepError: [{'code': 185, 'message': 'User is over daily status update limit.'}]
# INFO:root:Processing tweet id 1351542807811547139
# ERROR:root:Error on fav
# Traceback (most recent call last):
#   File "<ipython-input-4-c4d251994a9b>", line 48, in on_status
#     tweet.favorite()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\models.py", line 131, in favorite
#     return self._api.create_favorite(self.id)
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 253, in _call
#     return method.execute()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 234, in execute
#     raise TweepError(error_msg, resp, api_code=api_error_code)
# tweepy.error.TweepError: Twitter error response: status code = 429
# ERROR:root:Error on fav and retweet
# Traceback (most recent call last):
#   File "<ipython-input-4-c4d251994a9b>", line 54, in on_status
#     tweet.retweet()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\models.py", line 125, in retweet
#     return self._api.retweet(self.id)
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 253, in _call
#     return method.execute()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 234, in execute
#     raise TweepError(error_msg, resp, api_code=api_error_code)
# tweepy.error.TweepError: [{'code': 185, 'message': 'User is over daily status update limit.'}]
# INFO:root:Processing tweet id 1351542809615073286
# ERROR:root:Error on fav
# Traceback (most recent call last):
#   File "<ipython-input-4-c4d251994a9b>", line 48, in on_status
#     tweet.favorite()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\models.py", line 131, in favorite
#     return self._api.create_favorite(self.id)
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 253, in _call
#     return method.execute()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 234, in execute
#     raise TweepError(error_msg, resp, api_code=api_error_code)
# tweepy.error.TweepError: Twitter error response: status code = 429
# ERROR:root:Error on fav and retweet
# Traceback (most recent call last):
#   File "<ipython-input-4-c4d251994a9b>", line 54, in on_status
#     tweet.retweet()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\models.py", line 125, in retweet
#     return self._api.retweet(self.id)
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 253, in _call
#     return method.execute()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 234, in execute
#     raise TweepError(error_msg, resp, api_code=api_error_code)
# tweepy.error.TweepError: [{'code': 185, 'message': 'User is over daily status update limit.'}]
# INFO:root:Processing tweet id 1351542809698955267
# ERROR:root:Error on fav
# Traceback (most recent call last):
#   File "<ipython-input-4-c4d251994a9b>", line 48, in on_status
#     tweet.favorite()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\models.py", line 131, in favorite
#     return self._api.create_favorite(self.id)
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 253, in _call
#     return method.execute()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 234, in execute
#     raise TweepError(error_msg, resp, api_code=api_error_code)
# tweepy.error.TweepError: Twitter error response: status code = 429
# ERROR:root:Error on fav and retweet
# Traceback (most recent call last):
#   File "<ipython-input-4-c4d251994a9b>", line 54, in on_status
#     tweet.retweet()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\models.py", line 125, in retweet
#     return self._api.retweet(self.id)
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 253, in _call
#     return method.execute()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 234, in execute
#     raise TweepError(error_msg, resp, api_code=api_error_code)
# tweepy.error.TweepError: [{'code': 185, 'message': 'User is over daily status update limit.'}]
# INFO:root:Processing tweet id 1351542812572057606
# ERROR:root:Error on fav
# Traceback (most recent call last):
#   File "<ipython-input-4-c4d251994a9b>", line 48, in on_status
#     tweet.favorite()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\models.py", line 131, in favorite
#     return self._api.create_favorite(self.id)
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 253, in _call
#     return method.execute()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 234, in execute
#     raise TweepError(error_msg, resp, api_code=api_error_code)
# tweepy.error.TweepError: Twitter error response: status code = 429
# ERROR:root:Error on fav and retweet
# Traceback (most recent call last):
#   File "<ipython-input-4-c4d251994a9b>", line 54, in on_status
#     tweet.retweet()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\models.py", line 125, in retweet
#     return self._api.retweet(self.id)
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 253, in _call
#     return method.execute()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 234, in execute
#     raise TweepError(error_msg, resp, api_code=api_error_code)
# tweepy.error.TweepError: [{'code': 185, 'message': 'User is over daily status update limit.'}]
# INFO:root:Processing tweet id 1351542818045652993
# ERROR:root:Error on fav
# Traceback (most recent call last):
#   File "<ipython-input-4-c4d251994a9b>", line 48, in on_status
#     tweet.favorite()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\models.py", line 131, in favorite
#     return self._api.create_favorite(self.id)
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 253, in _call
#     return method.execute()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 234, in execute
#     raise TweepError(error_msg, resp, api_code=api_error_code)
# tweepy.error.TweepError: Twitter error response: status code = 429
# ERROR:root:Error on fav and retweet
# Traceback (most recent call last):
#   File "<ipython-input-4-c4d251994a9b>", line 54, in on_status
#     tweet.retweet()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\models.py", line 125, in retweet
#     return self._api.retweet(self.id)
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 253, in _call
#     return method.execute()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 234, in execute
#     raise TweepError(error_msg, resp, api_code=api_error_code)
# tweepy.error.TweepError: [{'code': 185, 'message': 'User is over daily status update limit.'}]
# INFO:root:Processing tweet id 1351542818116919297
# INFO:root:Processing tweet id 1351542825368907776
# INFO:root:Processing tweet id 1351542835279966209
# ERROR:root:Error on fav
# Traceback (most recent call last):
#   File "<ipython-input-4-c4d251994a9b>", line 48, in on_status
#     tweet.favorite()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\models.py", line 131, in favorite
#     return self._api.create_favorite(self.id)
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 253, in _call
#     return method.execute()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 234, in execute
#     raise TweepError(error_msg, resp, api_code=api_error_code)
# tweepy.error.TweepError: Twitter error response: status code = 429
# ERROR:root:Error on fav and retweet
# Traceback (most recent call last):
#   File "<ipython-input-4-c4d251994a9b>", line 54, in on_status
#     tweet.retweet()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\models.py", line 125, in retweet
#     return self._api.retweet(self.id)
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 253, in _call
#     return method.execute()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 234, in execute
#     raise TweepError(error_msg, resp, api_code=api_error_code)
# tweepy.error.TweepError: [{'code': 185, 'message': 'User is over daily status update limit.'}]
# INFO:root:Processing tweet id 1351542839809888257
# ERROR:root:Error on fav
# Traceback (most recent call last):
#   File "<ipython-input-4-c4d251994a9b>", line 48, in on_status
#     tweet.favorite()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\models.py", line 131, in favorite
#     return self._api.create_favorite(self.id)
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 253, in _call
#     return method.execute()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 234, in execute
#     raise TweepError(error_msg, resp, api_code=api_error_code)
# tweepy.error.TweepError: Twitter error response: status code = 429
# ERROR:root:Error on fav and retweet
# Traceback (most recent call last):
#   File "<ipython-input-4-c4d251994a9b>", line 54, in on_status
#     tweet.retweet()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\models.py", line 125, in retweet
#     return self._api.retweet(self.id)
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 253, in _call
#     return method.execute()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 234, in execute
#     raise TweepError(error_msg, resp, api_code=api_error_code)
# tweepy.error.TweepError: [{'code': 185, 'message': 'User is over daily status update limit.'}]
# INFO:root:Processing tweet id 1351542849435807746
# ERROR:root:Error on fav
# Traceback (most recent call last):
#   File "<ipython-input-4-c4d251994a9b>", line 48, in on_status
#     tweet.favorite()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\models.py", line 131, in favorite
#     return self._api.create_favorite(self.id)
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 253, in _call
#     return method.execute()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 234, in execute
#     raise TweepError(error_msg, resp, api_code=api_error_code)
# tweepy.error.TweepError: Twitter error response: status code = 429
# ERROR:root:Error on fav and retweet
# Traceback (most recent call last):
#   File "<ipython-input-4-c4d251994a9b>", line 54, in on_status
#     tweet.retweet()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\models.py", line 125, in retweet
#     return self._api.retweet(self.id)
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 253, in _call
#     return method.execute()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 234, in execute
#     raise TweepError(error_msg, resp, api_code=api_error_code)
# tweepy.error.TweepError: [{'code': 185, 'message': 'User is over daily status update limit.'}]
# INFO:root:Processing tweet id 1351542854322159620
# ERROR:root:Error on fav
# Traceback (most recent call last):
#   File "<ipython-input-4-c4d251994a9b>", line 48, in on_status
#     tweet.favorite()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\models.py", line 131, in favorite
#     return self._api.create_favorite(self.id)
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 253, in _call
#     return method.execute()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 234, in execute
#     raise TweepError(error_msg, resp, api_code=api_error_code)
# tweepy.error.TweepError: Twitter error response: status code = 429
# ERROR:root:Error on fav and retweet
# Traceback (most recent call last):
#   File "<ipython-input-4-c4d251994a9b>", line 54, in on_status
#     tweet.retweet()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\models.py", line 125, in retweet
#     return self._api.retweet(self.id)
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 253, in _call
#     return method.execute()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 234, in execute
#     raise TweepError(error_msg, resp, api_code=api_error_code)
# tweepy.error.TweepError: [{'code': 185, 'message': 'User is over daily status update limit.'}]
# INFO:root:Processing tweet id 1351542864128450562
# ERROR:root:Error on fav
# Traceback (most recent call last):
#   File "<ipython-input-4-c4d251994a9b>", line 48, in on_status
#     tweet.favorite()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\models.py", line 131, in favorite
#     return self._api.create_favorite(self.id)
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 253, in _call
#     return method.execute()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 234, in execute
#     raise TweepError(error_msg, resp, api_code=api_error_code)
# tweepy.error.TweepError: Twitter error response: status code = 429
# ERROR:root:Error on fav and retweet
# Traceback (most recent call last):
#   File "<ipython-input-4-c4d251994a9b>", line 54, in on_status
#     tweet.retweet()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\models.py", line 125, in retweet
#     return self._api.retweet(self.id)
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 253, in _call
#     return method.execute()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 234, in execute
#     raise TweepError(error_msg, resp, api_code=api_error_code)
# tweepy.error.TweepError: [{'code': 185, 'message': 'User is over daily status update limit.'}]
# INFO:root:Processing tweet id 1351542868360515584
# ERROR:root:Error on fav
# Traceback (most recent call last):
#   File "<ipython-input-4-c4d251994a9b>", line 48, in on_status
#     tweet.favorite()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\models.py", line 131, in favorite
#     return self._api.create_favorite(self.id)
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 253, in _call
#     return method.execute()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 234, in execute
#     raise TweepError(error_msg, resp, api_code=api_error_code)
# tweepy.error.TweepError: Twitter error response: status code = 429
# ERROR:root:Error on fav and retweet
# Traceback (most recent call last):
#   File "<ipython-input-4-c4d251994a9b>", line 54, in on_status
#     tweet.retweet()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\models.py", line 125, in retweet
#     return self._api.retweet(self.id)
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 253, in _call
#     return method.execute()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 234, in execute
#     raise TweepError(error_msg, resp, api_code=api_error_code)
# tweepy.error.TweepError: [{'code': 185, 'message': 'User is over daily status update limit.'}]
# INFO:root:Processing tweet id 1351542882730184706
# INFO:root:Processing tweet id 1351542887977263106
# INFO:root:Processing tweet id 1351542890405777410
# ERROR:root:Error on fav
# Traceback (most recent call last):
#   File "<ipython-input-4-c4d251994a9b>", line 48, in on_status
#     tweet.favorite()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\models.py", line 131, in favorite
#     return self._api.create_favorite(self.id)
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 253, in _call
#     return method.execute()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 234, in execute
#     raise TweepError(error_msg, resp, api_code=api_error_code)
# tweepy.error.TweepError: Twitter error response: status code = 429
# ERROR:root:Error on fav and retweet
# Traceback (most recent call last):
#   File "<ipython-input-4-c4d251994a9b>", line 54, in on_status
#     tweet.retweet()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\models.py", line 125, in retweet
#     return self._api.retweet(self.id)
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 253, in _call
#     return method.execute()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 234, in execute
#     raise TweepError(error_msg, resp, api_code=api_error_code)
# tweepy.error.TweepError: [{'code': 185, 'message': 'User is over daily status update limit.'}]
# INFO:root:Processing tweet id 1351542894411309062
# ERROR:root:Error on fav
# Traceback (most recent call last):
#   File "<ipython-input-4-c4d251994a9b>", line 48, in on_status
#     tweet.favorite()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\models.py", line 131, in favorite
#     return self._api.create_favorite(self.id)
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 253, in _call
#     return method.execute()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 234, in execute
#     raise TweepError(error_msg, resp, api_code=api_error_code)
# tweepy.error.TweepError: Twitter error response: status code = 429
# ERROR:root:Error on fav and retweet
# Traceback (most recent call last):
#   File "<ipython-input-4-c4d251994a9b>", line 54, in on_status
#     tweet.retweet()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\models.py", line 125, in retweet
#     return self._api.retweet(self.id)
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 253, in _call
#     return method.execute()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 234, in execute
#     raise TweepError(error_msg, resp, api_code=api_error_code)
# tweepy.error.TweepError: [{'code': 185, 'message': 'User is over daily status update limit.'}]
# INFO:root:Processing tweet id 1351542899880701955
# ERROR:root:Error on fav
# Traceback (most recent call last):
#   File "<ipython-input-4-c4d251994a9b>", line 48, in on_status
#     tweet.favorite()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\models.py", line 131, in favorite
#     return self._api.create_favorite(self.id)
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 253, in _call
#     return method.execute()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 234, in execute
#     raise TweepError(error_msg, resp, api_code=api_error_code)
# tweepy.error.TweepError: Twitter error response: status code = 429
# ERROR:root:Error on fav and retweet
# Traceback (most recent call last):
#   File "<ipython-input-4-c4d251994a9b>", line 54, in on_status
#     tweet.retweet()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\models.py", line 125, in retweet
#     return self._api.retweet(self.id)
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 253, in _call
#     return method.execute()
#   File "C:\Users\Alberto\anaconda3\lib\site-packages\tweepy\binder.py", line 234, in execute
#     raise TweepError(error_msg, resp, api_code=api_error_code)
# tweepy.error.TweepError: [{'code': 185, 'message': 'User is over daily status update limit.'}]
